# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmetdamkaci/Monophonic_Pitch_Detection/blob/main/TinySOL_pitchDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://zenodo.org/record/3685331/files/TinySOL.tar.gz
# Out:
# --2023-04-10 14:50:55--  https://zenodo.org/record/3685331/files/TinySOL.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1026941458 (979M) [application/octet-stream]
# Saving to: ‘TinySOL.tar.gz’
#
# TinySOL.tar.gz        3%[                    ]  29.85M   513KB/s    eta 31m 38s

# %%
# !gunzip < TinySOL.tar.gz | tar xvf -

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
csvDataset=pd.read_csv('/content/gdrive/MyDrive/TinySOL Musical Note Recognation/Dataset/TinySOL_metadata.csv')
csvDataset.head()
# Out:
# Mounted at /content/gdrive
#                                                 Path  Fold Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav     2  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...     4  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...     3  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...     2  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav     0  Brass
#
#   Instrument (abbr.) Instrument (in full) Technique (abbr.)  \
# 0                BTb            Bass Tuba               ord
# 1                BTb            Bass Tuba               ord
# 2                BTb            Bass Tuba               ord
# 3                BTb            Bass Tuba               ord
# 4                BTb            Bass Tuba               ord
#
#   Technique (in full) Pitch  Pitch ID Dynamics  Dynamics ID  Instance ID  \
# 0           ordinario   F#1        30       pp            0            0
# 1           ordinario    G1        31       pp            0            0
# 2           ordinario   G#1        32       pp            0            0
# 3           ordinario    A1        33       pp            0            0
# 4           ordinario   A#1        34       pp            0            0
#
#    String ID (if applicable)  Needed digital retuning
# 0                        NaN                    False
# 1                        NaN                     True
# 2                        NaN                     True
# 3                        NaN                     True
# 4                        NaN                    False

# %%
csvInstrument=csvDataset[['Instrument (in full)','Pitch']]
Pitchs=csvDataset['Pitch'].unique()
Instruments=csvDataset['Instrument (in full)'].unique()
csvInstrument.loc[(csvInstrument['Pitch']==Pitchs[0]) & (csvInstrument['Instrument (in full)']==Instruments[0])]

liste=list()
for instrument in Instruments:
  liste.append([len(csvInstrument.loc[(csvInstrument['Pitch']==pitch) & (csvInstrument['Instrument (in full)']==instrument)]) for pitch in Pitchs])
pitchTable=pd.DataFrame(liste, index=Instruments, columns=Pitchs)

liste=pitchTable.columns
num_list=list()
for i in liste:
  num_list.append(len(pitchTable.loc[pitchTable[i]!=0]))

pitchDistr=pd.DataFrame(num_list, columns=['Num_Instrument'], index=liste)

delpitch=list()
pitchSelect=list()
pitchIDSelect=list()
pitchClass=pitchDistr.loc[pitchDistr['Num_Instrument']>1].index
for pitch in pitchClass:
  if len(csvDataset.loc[(csvDataset['Pitch']==pitch)])>=10:
    pitchSelect.append(pitch)
    pitchIDSelect.append(csvDataset.loc[(csvDataset['Pitch']==pitch)]['Pitch ID'].iloc[0])
  else:
    delpitch.append(pitch)
print(f'Length Of pitchSelect : {len(pitchSelect)}')
print(f'Length Of pitchIDSelect : {len(pitchIDSelect)}')
# Out:
# Length Of pitchSelect : 71
# Length Of pitchIDSelect : 71

# %%
newFrame=csvDataset.loc[csvDataset['Pitch'].isin(pitchSelect)]
newFrame
# Out:
#                                                    Path  Fold Family  \
# 0      Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav     2  Brass
# 1     Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...     4  Brass
# 2     Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...     3  Brass
# 3     Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...     2  Brass
# 4      Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav     0  Brass
# ...                                                 ...   ...    ...
# 2908          Winds/Oboe/ordinario/Ob-ord-F6-ff-N-N.wav     2  Winds
# 2909      Winds/Oboe/ordinario/Ob-ord-F#6-ff-N-T12u.wav     0  Winds
# 2910       Winds/Oboe/ordinario/Ob-ord-G6-ff-N-T16u.wav     0  Winds
# 2911         Winds/Oboe/ordinario/Ob-ord-G#6-ff-N-N.wav     0  Winds
# 2912       Winds/Oboe/ordinario/Ob-ord-A6-ff-N-T18u.wav     1  Winds
#
#      Instrument (abbr.) Instrument (in full) Technique (abbr.)  \
# 0                   BTb            Bass Tuba               ord
# 1                   BTb            Bass Tuba               ord
# 2                   BTb            Bass Tuba               ord
# 3                   BTb            Bass Tuba               ord
# 4                   BTb            Bass Tuba               ord
# ...                 ...                  ...               ...
# 2908                 Ob                 Oboe               ord
# 2909                 Ob                 Oboe               ord
# 2910                 Ob                 Oboe               ord
# 2911                 Ob                 Oboe               ord
# 2912                 Ob                 Oboe               ord
#
#      Technique (in full) Pitch  Pitch ID Dynamics  Dynamics ID  Instance ID  \
# 0              ordinario   F#1        30       pp            0            0
# 1              ordinario    G1        31       pp            0            0
# 2              ordinario   G#1        32       pp            0            0
# 3              ordinario    A1        33       pp            0            0
# 4              ordinario   A#1        34       pp            0            0
# ...                  ...   ...       ...      ...          ...          ...
# 2908           ordinario    F6        89       ff            4            0
# 2909           ordinario   F#6        90       ff            4            0
# 2910           ordinario    G6        91       ff            4            0
# 2911           ordinario   G#6        92       ff            4            0
# 2912           ordinario    A6        93       ff            4            0
#
#       String ID (if applicable)  Needed digital retuning
# 0                           NaN                    False
# 1                           NaN                     True
# 2                           NaN                     True
# 3                           NaN                     True
# 4                           NaN                    False
# ...                         ...                      ...
# 2908                        NaN                    False
# 2909                        NaN                     True
# 2910                        NaN                     True
# 2911                        NaN                    False
# 2912                        NaN                     True
#
# [2854 rows x 14 columns]

# %%
import numpy as np
import librosa
from tqdm import tqdm
import numpy as np
import librosa.display
import matplotlib.pyplot as plt
import random

numOfRow=1025
numOfColumn=42

numClass=len(pitchIDSelect)
def oneHotEnc(number):
  label=np.zeros((numClass), dtype=np.uint8)
  label[number-min(pitchIDSelect)]=1
  return label

def setData(Data, Label, pathList, pitchIDList):
  pbar=tqdm(total=len(pathList))
  filePath='/content/TinySOL/'
  for index, (path, note) in enumerate(zip(pathList,pitchIDList)):
    data=librosa.load(filePath+path, sr=16000)[0]
    stftWav=librosa.stft(data, n_fft=2048)
    Data[index]=np.log10(np.abs(stftWav[:,:numOfColumn]))
    Label[index]=oneHotEnc(note)  
    pbar.update(1)
  pbar.close()
  return Data, Label

# Verileri görselleştirir.
def drawSpec(data, label):

  plt.figure(figsize=(25,10))
  for i in range(8):
    index=random.randint(0,len(data))
    plt.subplot(2, 4, i+1)
    librosa.display.specshow(data[index].reshape(numOfRow,numOfColumn), sr=16000, 
                             hop_length=2048//4, x_axis='s', y_axis='hz', cmap='viridis')
    plt.title(np.where(label[index]==1)[0][0])
  plt.show()

# %%
trainPath=newFrame['Path']
pitchIDList=newFrame['Pitch ID']
trainData=np.zeros((len(trainPath), numOfRow, numOfColumn), dtype=np.float32)
trainLabel=np.zeros((len(trainPath),numClass), dtype=np.uint8)

trainData, trainLabel=setData(trainData, trainLabel, trainPath, pitchIDList)
print(f'\nShape Of Train Data : {trainData.shape}')
print(f'Shape Of Train Label : {trainLabel.shape}')

np.save('/content/gdrive/MyDrive/TinySOL Musical Note Recognation/Dataset/trainData16_71Class.npy', trainData)
np.save('/content/gdrive/MyDrive/TinySOL Musical Note Recognation/Dataset/trainLabel16_71Class.npy', trainLabel)

# %%
drawSpec(trainData, trainLabel)

# %% [markdown]
# #Train

# %%
import numpy as np
from google.colab import drive

drive.mount('/content/gdrive')
trainData=np.load('/content/gdrive/MyDrive/TinySOL Musical Note Recognation/Dataset/trainData16_71Class.npy')
trainLabel=np.load('/content/gdrive/MyDrive/TinySOL Musical Note Recognation/Dataset/trainLabel16_71Class.npy')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf

class CustomAttentionLayer(tf.keras.layers.Layer):
    def __init__(self,  activation=None):
        super(CustomAttentionLayer, self).__init__()
        self.activation = tf.keras.activations.get(activation)

    def build(self, input_shape):

        self.input_dim = input_shape[-1]
        self.w = self.add_weight(
            shape=(self.input_dim,1),
            initializer="random_normal",
            trainable=True,
        )        

    def call(self, inputs):        
        
        alphaVector = tf.reshape(self.activation(self.w), shape=[32,])
        # attentionVector = tf.keras.layers.Softmax(axis=0)(alphaVector)
        
        #output = inputs*attentionVector
        
        return alphaVector

input_tensor = tf.keras.layers.Input(shape=(7,6,32), batch_size=None)
layer = CustomAttentionLayer(activation='tanh')(input_tensor)
layer.shape
# Out:
# TensorShape([32])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Input, Dense, Flatten, Dropout, Resizing, BatchNormalization, Activation, Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Model

def buildModel(inputAudio):

  layer1 = Conv2D(32, 3, activation='relu')(inputAudio)  
  layerb = BatchNormalization()(layer1)
  layer2 = MaxPooling2D()(layerb)
  layerd = Dropout(0.25)(layer2)
  layer3 = Conv2D(32, 3, activation='relu')(layerd)  
  layer4 = MaxPooling2D()(layer3)
  layerd1 = Dropout(0.25)(layer4)
  layer5 = Conv2D(32, 3, activation='relu')(layerd1)
  layer6 = MaxPooling2D()(layer5)  
  layerd2 = Dropout(0.25)(layer6)
  layer7 = Conv2D(32, 3, activation='relu')(layerd2)

  attention2D = Conv2D(32, 3, activation=None, padding = 'same')(layer7)
  attentionMap = tf.keras.layers.Softmax()(attention2D)
  multiplyLayer = tf.keras.layers.Multiply()([layer7, attentionMap])

  # alphaLayer = CustomAttentionLayer(activation='tanh')(layer7)
  # attentionLayer = tf.keras.layers.Softmax()(alphaLayer)
  # multiplyLayer = layer7*attentionLayer

  #layer8 = MaxPooling2D()(layer7)  
  layer9 = Dropout(0.25)(multiplyLayer)   
  layer10 = Flatten()(layer9)
  layer11 = Dense(512, activation='relu')(layer10)
  layerd3 = Dropout(0.25)(layer11)  
  layer13 = Dense(128, activation='relu')(layerd3)   
  layerd4 = Dropout(0.25)(layer13)  
  layer14 = Dense(71, activation='softmax')(layerd4) 

  return layer14

numOfRow=1025
numOfColumn=42
inputSignal = Input(shape=(numOfRow, numOfColumn, 1))
model=Model(inputs=inputSignal, outputs=buildModel(inputSignal))
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 1025, 42, 1  0           []
#                                 )]
#
#  conv2d_14 (Conv2D)             (None, 1023, 40, 32  320         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 1023, 40, 32  128        ['conv2d_14[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 511, 20, 32)  0          ['batch_normalization_3[0][0]']
#
#  dropout_15 (Dropout)           (None, 511, 20, 32)  0           ['max_pooling2d_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 509, 18, 32)  9248        ['dropout_15[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 254, 9, 32)  0           ['conv2d_15[0][0]']
#  )
#
#  dropout_16 (Dropout)           (None, 254, 9, 32)   0           ['max_pooling2d_10[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 252, 7, 32)   9248        ['dropout_16[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 126, 3, 32)  0           ['conv2d_16[0][0]']
#  )
#
#  dropout_17 (Dropout)           (None, 126, 3, 32)   0           ['max_pooling2d_11[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 124, 1, 32)   9248        ['dropout_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 124, 1, 32)   9248        ['conv2d_17[0][0]']
#
#  softmax_2 (Softmax)            (None, 124, 1, 32)   0           ['conv2d_18[0][0]']
#
#  multiply_2 (Multiply)          (None, 124, 1, 32)   0           ['conv2d_17[0][0]',
#                                                                   'softmax_2[0][0]']
#
#  dropout_18 (Dropout)           (None, 124, 1, 32)   0           ['multiply_2[0][0]']
#
#  flatten_2 (Flatten)            (None, 3968)         0           ['dropout_18[0][0]']
#
#  dense_6 (Dense)                (None, 512)          2032128     ['flatten_2[0][0]']
#
#  dropout_19 (Dropout)           (None, 512)          0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 128)          65664       ['dropout_19[0][0]']
#
#  dropout_20 (Dropout)           (None, 128)          0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 71)           9159        ['dropout_20[0][0]']
#
# ==================================================================================================
# Total params: 2,144,391
# Trainable params: 2,144,327
# Non-trainable params: 64
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

filepath='/content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5'
checkpoint = ModelCheckpoint(filepath, monitor='accuracy',verbose=2, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

#validation=(validationData, validationLabel)
batch_size=32
epochs=30

hist=model.fit( trainData,
                trainLabel,
                epochs=epochs,
                shuffle=True,
                batch_size=batch_size,
                verbose=2,
                validation_split=0.15,
                callbacks=callbacks_list)
# Out:
# Epoch 1/30
#
# Epoch 1: accuracy improved from -inf to 0.37608, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 22s - loss: 2.7476 - accuracy: 0.3761 - val_loss: 3.7641 - val_accuracy: 0.8695 - 22s/epoch - 283ms/step
# Epoch 2/30
#
# Epoch 2: accuracy improved from 0.37608 to 0.83423, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.6722 - accuracy: 0.8342 - val_loss: 2.7600 - val_accuracy: 0.9604 - 5s/epoch - 70ms/step
# Epoch 3/30
#
# Epoch 3: accuracy improved from 0.83423 to 0.89072, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.4161 - accuracy: 0.8907 - val_loss: 0.8580 - val_accuracy: 0.9744 - 5s/epoch - 69ms/step
# Epoch 4/30
#
# Epoch 4: accuracy improved from 0.89072 to 0.91959, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.2781 - accuracy: 0.9196 - val_loss: 0.2089 - val_accuracy: 0.9883 - 5s/epoch - 70ms/step
# Epoch 5/30
#
# Epoch 5: accuracy improved from 0.91959 to 0.92866, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.2467 - accuracy: 0.9287 - val_loss: 0.0407 - val_accuracy: 0.9977 - 5s/epoch - 70ms/step
# Epoch 6/30
#
# Epoch 6: accuracy improved from 0.92866 to 0.95299, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.1491 - accuracy: 0.9530 - val_loss: 0.0258 - val_accuracy: 0.9977 - 5s/epoch - 70ms/step
# Epoch 7/30
#
# Epoch 7: accuracy improved from 0.95299 to 0.96041, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.1420 - accuracy: 0.9604 - val_loss: 0.0177 - val_accuracy: 0.9977 - 5s/epoch - 71ms/step
# Epoch 8/30
#
# Epoch 8: accuracy improved from 0.96041 to 0.96907, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.1124 - accuracy: 0.9691 - val_loss: 0.0152 - val_accuracy: 0.9977 - 5s/epoch - 70ms/step
# Epoch 9/30
#
# Epoch 9: accuracy improved from 0.96907 to 0.97237, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.0828 - accuracy: 0.9724 - val_loss: 0.0063 - val_accuracy: 0.9977 - 5s/epoch - 70ms/step
# Epoch 10/30
#
# Epoch 10: accuracy improved from 0.97237 to 0.97443, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.0872 - accuracy: 0.9744 - val_loss: 0.0691 - val_accuracy: 0.9930 - 5s/epoch - 70ms/step
# Epoch 11/30
#
# Epoch 11: accuracy did not improve from 0.97443
# 76/76 - 5s - loss: 0.0899 - accuracy: 0.9744 - val_loss: 0.0361 - val_accuracy: 0.9883 - 5s/epoch - 67ms/step
# Epoch 12/30
#
# Epoch 12: accuracy improved from 0.97443 to 0.98887, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 6s - loss: 0.0522 - accuracy: 0.9889 - val_loss: 0.0044 - val_accuracy: 1.0000 - 6s/epoch - 79ms/step
# Epoch 13/30
#
# Epoch 13: accuracy improved from 0.98887 to 0.99216, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.0510 - accuracy: 0.9922 - val_loss: 0.0127 - val_accuracy: 0.9953 - 5s/epoch - 70ms/step
# Epoch 14/30
#
# Epoch 14: accuracy did not improve from 0.99216
# 76/76 - 5s - loss: 0.0306 - accuracy: 0.9909 - val_loss: 0.0039 - val_accuracy: 1.0000 - 5s/epoch - 71ms/step
# Epoch 15/30
#
# Epoch 15: accuracy did not improve from 0.99216
# 76/76 - 5s - loss: 0.0292 - accuracy: 0.9918 - val_loss: 0.0039 - val_accuracy: 1.0000 - 5s/epoch - 69ms/step
# Epoch 16/30
#
# Epoch 16: accuracy did not improve from 0.99216
# 76/76 - 5s - loss: 0.0303 - accuracy: 0.9913 - val_loss: 0.0120 - val_accuracy: 0.9930 - 5s/epoch - 67ms/step
# Epoch 17/30
#
# Epoch 17: accuracy did not improve from 0.99216
# 76/76 - 5s - loss: 0.0579 - accuracy: 0.9868 - val_loss: 7.8391e-04 - val_accuracy: 1.0000 - 5s/epoch - 70ms/step
# Epoch 18/30
#
# Epoch 18: accuracy did not improve from 0.99216
# 76/76 - 5s - loss: 0.0411 - accuracy: 0.9922 - val_loss: 0.0065 - val_accuracy: 0.9953 - 5s/epoch - 67ms/step
# Epoch 19/30
#
# Epoch 19: accuracy improved from 0.99216 to 0.99258, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 6s - loss: 0.0464 - accuracy: 0.9926 - val_loss: 0.0112 - val_accuracy: 1.0000 - 6s/epoch - 78ms/step
# Epoch 20/30
#
# Epoch 20: accuracy improved from 0.99258 to 0.99423, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.0210 - accuracy: 0.9942 - val_loss: 0.0050 - val_accuracy: 0.9977 - 5s/epoch - 70ms/step
# Epoch 21/30
#
# Epoch 21: accuracy did not improve from 0.99423
# 76/76 - 5s - loss: 0.0238 - accuracy: 0.9922 - val_loss: 0.0047 - val_accuracy: 0.9977 - 5s/epoch - 68ms/step
# Epoch 22/30
#
# Epoch 22: accuracy did not improve from 0.99423
# 76/76 - 5s - loss: 0.0275 - accuracy: 0.9930 - val_loss: 0.0026 - val_accuracy: 1.0000 - 5s/epoch - 69ms/step
# Epoch 23/30
#
# Epoch 23: accuracy improved from 0.99423 to 0.99629, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 6s - loss: 0.0142 - accuracy: 0.9963 - val_loss: 3.6838e-04 - val_accuracy: 1.0000 - 6s/epoch - 77ms/step
# Epoch 24/30
#
# Epoch 24: accuracy improved from 0.99629 to 1.00000, saving model to /content/gdrive/MyDrive/TinySOL Musical Note Recognation/Models/Model_TinySOL_71Class_attention_Conv2D.h5
# 76/76 - 5s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.9406e-04 - val_accuracy: 1.0000 - 5s/epoch - 70ms/step
# Epoch 25/30
#
# Epoch 25: accuracy did not improve from 1.00000
# 76/76 - 5s - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.0218 - val_accuracy: 0.9953 - 5s/epoch - 69ms/step
# Epoch 26/30
#
# Epoch 26: accuracy did not improve from 1.00000
# 76/76 - 5s - loss: 0.0325 - accuracy: 0.9967 - val_loss: 0.0107 - val_accuracy: 0.9953 - 5s/epoch - 68ms/step
# Epoch 27/30
#
# Epoch 27: accuracy did not improve from 1.00000
# 76/76 - 5s - loss: 0.0424 - accuracy: 0.9938 - val_loss: 0.0076 - val_accuracy: 1.0000 - 5s/epoch - 69ms/step
# Epoch 28/30
#
# Epoch 28: accuracy did not improve from 1.00000
# 76/76 - 5s - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.0021 - val_accuracy: 1.0000 - 5s/epoch - 68ms/step
# Epoch 29/30
#
# Epoch 29: accuracy did not improve from 1.00000
# 76/76 - 5s - loss: 0.0299 - accuracy: 0.9963 - val_loss: 0.0468 - val_accuracy: 0.9953 - 5s/epoch - 67ms/step
# Epoch 30/30
#
# Epoch 30: accuracy did not improve from 1.00000
# 76/76 - 5s - loss: 0.0134 - accuracy: 0.9979 - val_loss: 0.0100 - val_accuracy: 0.9977 - 5s/epoch - 68ms/step
